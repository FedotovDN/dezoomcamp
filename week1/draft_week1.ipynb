# %%
import pandas as pd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data = pd.read_csv('yellow_tripdata_2021-01.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.tpep_pickup_datetime = pd.to_datetime(data.tpep_pickup_datetime)
data.tpep_dropoff_datetime = pd.to_datetime(data.tpep_dropoff_datetime)

# %% [markdown]
# ### Question 3

# %%
data[(data.tpep_pickup_datetime >= '2021-01-15') & (data.tpep_pickup_datetime < '2021-01-16')]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 552720        2.0  2021-01-15 00:03:53   2021-01-15 00:40:08              1.0
# 553208        1.0  2021-01-15 00:53:53   2021-01-15 01:01:12              1.0
# 553209        1.0  2021-01-15 00:00:14   2021-01-15 00:15:04              1.0
# 553210        2.0  2021-01-15 00:01:02   2021-01-15 00:05:12              1.0
# 553211        2.0  2021-01-15 00:42:40   2021-01-15 00:45:27              5.0
# ...           ...                  ...                   ...              ...
# 1340868       NaN  2021-01-15 15:44:21   2021-01-15 16:02:10              NaN
# 1340869       NaN  2021-01-15 15:16:05   2021-01-15 15:32:31              NaN
# 1340870       NaN  2021-01-15 15:43:00   2021-01-15 15:56:00              NaN
# 1340871       NaN  2021-01-15 15:13:00   2021-01-15 15:21:00              NaN
# 1340872       NaN  2021-01-15 15:08:00   2021-01-15 16:24:00              NaN
#
# ...

# %% [markdown]
# ### Question 4

# %%
data.sort_values(by='tip_amount').tail(1)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 764800       1.0  2021-01-20 11:22:05   2021-01-20 19:47:56              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 764800          427.7         1.0                  Y             4
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 764800           265           1.0       1128.5    2.5      0.5     1140.44
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 764800         20.16                    0.3        2292.4
#
#         congestion_surcharge
# 764800                   2.5

# %% [markdown]
# ### Question 5

# %%
data[(data['tpep_pickup_datetime'] >= '2021-01-14') & (data['tpep_pickup_datetime'] < '2021-01-15') & (data.PULocationID == 43)].groupby(by='DOLocationID').count().sort_values(by='VendorID')
# Out:
#               VendorID  tpep_pickup_datetime  tpep_dropoff_datetime  \
# DOLocationID
# 71                   0                     1                      1
# 80                   0                     1                      1
# 183                  0                     1                      1
# 62                   0                     1                      1
# 209                  0                     1                      1
# ...                ...                   ...                    ...
# 239                 59                    60                     60
# 238                 64                    68                     68
# 142                 82                    83                     83
# 236                 93                    94                     94
# 237                 96                    97                     97
#
#               passenger_count  trip_distance  RatecodeID  store_and_fwd_flag  \
# DOLocationID
# ...

# %% [markdown]
# ### Question 6

# %%
data.groupby(by=['PULocationID', 'DOLocationID']).mean().sort_values(by='total_amount')
# Out:
#                            VendorID  passenger_count  trip_distance  \
# PULocationID DOLocationID
# 186          124           2.000000              1.0         14.170
# 68           192           2.000000              1.0         12.200
# 28           253                NaN              NaN          5.050
# 148          173           2.000000              1.0         11.705
# 79           175           2.000000              1.0         15.120
# ...                             ...              ...            ...
# 25           260           2.000000              2.0          8.240
# 145          48            1.500000              1.5          2.875
# 177          265           2.000000              1.0         44.350
# 234          39            1.333333              1.0         73.854
# 4            265           1.000000              1.0        427.700
#
#                            RatecodeID  payment_type  fare_amount  extra  \
# PULocationID DOLocationID
# ...
